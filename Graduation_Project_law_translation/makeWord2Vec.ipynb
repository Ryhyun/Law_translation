# %%
from konlpy.tag import Mecab
import sys
import re
import codecs
from gensim.models import Word2Vec
from gensim.models.keyedvectors import KeyedVectors
from gensim.models import FastText as fText

from sklearn.cluster import KMeans

# %%
test = []

pattern = "SSO|SSC|SC|SE|SW|SH|SY|SF|SN"
pos_tagger =Mecab()
nnpattern = "NNG|NNP"
def tokenize_basic(doc):
    a= []
    for t in pos_tagger.pos(doc):
        if( re.search(pattern, t[1]) != None):
            continue
        else:
            a.append('/'.join(t))
    return a

def tokenize_n(doc):
    pos_tagger =Mecab()

    a= []
    for t in pos_tagger.pos(doc):
        if( re.search(nnpattern, t[1]) != None):
            a.append('/'.join(t))
        else:
            continue;
    return a

# %%
tokenize_basic( "원룸계약을 해지하고 싶어요")
# Out:
# ['원룸/NNG', '계약/NNG', '을/JKO', '해지/NNG', '하/XSV', '고/EC', '싶/VX', '어요/EF']

# %%
class SentenceReader:

    def __init__(self, filepath):
        self.filepath = filepath
        self.count = 0 ;

    def __iter__(self):
        for line in codecs.open(self.filepath, encoding='utf-8'):
            self.count += 1 
            if( self.count % 10000 == 0):
                print(self.count)
            yield tokenize_basic(line)
            
            
class SentenceReader_n:

    def __init__(self, filepath):
        self.filepath = filepath
        self.count = 0 ;

    def __iter__(self):
        for line in codecs.open(self.filepath, encoding='utf-8'):
            self.count += 1 
            if( self.count % 10000 == 0):
                print(self.count)
            yield tokenize_n(line)

# %%
civil_law = SentenceReader("model/civil_law.txt")
real_estate_law =  SentenceReader("model/real_estate_law.txt")
traffic_law =SentenceReader("model/traffic.txt")


civil_law_n = SentenceReader_n("model/civil_law.txt")
real_estate_law_n =  SentenceReader_n("model/real_estate_law.txt")
traffic_law_n =SentenceReader_n("model/traffic.txt")

# %%
civil_model_n = Word2Vec(civil_law_n, size=100, window = 3, min_count=10, workers=4, iter=100, sg=1)
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# ...

# %%
civil_model_n.save('model/traffic_law_n')

# %%
civil_model_n

# %%
traffic_model = Word2Vec(traffic_law, size=100, window = 3, min_count=10, workers=4, iter=100, sg=1)
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# ...

# %%
civil_model = Word2Vec(civil_law, size=100, window = 3, min_count=10, workers=4, iter=100, sg=1)
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# ...

# %%
real_estate_model = Word2Vec(real_estate_law, size=100, window = 3, min_count=10, workers=4, iter=100, sg=1)
# Out:
# 10000
# 20000
# 30000
# 40000
# 50000
# 60000
# 70000
# 80000
# 90000
# 100000
# 110000
# 120000
# 130000
# 140000
# 150000
# 160000
# 170000
# 180000
# 190000
# 200000
# 210000
# 220000
# 230000
# 240000
# 250000
# 260000
# 270000
# 280000
# 290000
# 300000
# 310000
# 320000
# 330000
# 340000
# 350000
# 360000
# 370000
# 380000
# 390000
# 400000
# 410000
# 420000
# 430000
# 440000
# 450000
# 460000
# 470000
# 480000
# 490000
# 500000
# 510000
# 520000
# 530000
# 540000
# 550000
# 560000
# 570000
# 580000
# 590000
# 600000
# 610000
# 620000
# 630000
# 640000
# 650000
# 660000
# 670000
# 680000
# 690000
# 700000
# 710000
# 720000
# 730000
# 740000
# 750000
# 760000
# 770000
# 780000
# 790000
# 800000
# 810000
# 820000
# 830000
# 840000
# 850000
# 860000
# 870000
# 880000
# 890000
# 900000
# 910000
# 920000
# 930000
# 940000
# 950000
# 960000
# 970000
# 980000
# 990000
# 1000000
# 1010000
# 1020000
# 1030000
# 1040000
# 1050000
# 1060000
# 1070000
# 1080000
# 1090000
# 1100000
# ...

# %%
real_estate_model.save('model/real_estate_law')

# %%
traffic_model.save('model/traffic_law')

# %%
civil_model.wv.vocab
# Out:
# {'상속/NNG': <gensim.models.keyedvectors.Vocab at 0x1181fd748>,
#  '포기/NNG': <gensim.models.keyedvectors.Vocab at 0x11288c898>,
#  '에/JKB': <gensim.models.keyedvectors.Vocab at 0x114a00ba8>,
#  '대해서/VV+EC': <gensim.models.keyedvectors.Vocab at 0x11827d898>,
#  '질문/NNG': <gensim.models.keyedvectors.Vocab at 0x11827d7f0>,
#  '드립니다/VV+EF': <gensim.models.keyedvectors.Vocab at 0x11827d128>,
#  '안녕/NNG': <gensim.models.keyedvectors.Vocab at 0x11827d278>,
#  '하/XSV': <gensim.models.keyedvectors.Vocab at 0x11832fb00>,
#  '세요/EP+EF': <gensim.models.keyedvectors.Vocab at 0x11832fb70>,
#  '아버님/NNG': <gensim.models.keyedvectors.Vocab at 0x11832f908>,
#  '이/JKS': <gensim.models.keyedvectors.Vocab at 0x11832f438>,
#  '돌아가/VV': <gensim.models.keyedvectors.Vocab at 0x11832fc50>,
#  '신/EP+ETM': <gensim.models.keyedvectors.Vocab at 0x11832f320>,
#  '후/NNG': <gensim.models.keyedvectors.Vocab at 0x11832f4e0>,
#  '어머님/NNG': <gensim.models.keyedvectors.Vocab at 0x11832fda0>,
# ...

# %%
real_estate_model.most_similar('보증금/NNG', topn =20)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('전세금/NNG', 0.8188802599906921),
#  ('반환/NNG', 0.5932586193084717),
#  ('계약금/NNG', 0.5400566458702087),
#  ('전액/NNG', 0.5162363052368164),
#  ('잔금/NNG', 0.4912337064743042),
#  ('차임/NNG', 0.48645710945129395),
#  ('제하/VV', 0.4853683412075043),
#  ('월세/NNG', 0.48514673113822937),
#  ('금액/NNG', 0.47692930698394775),
#  ('전세/NNG', 0.4608275294303894),
#  ('만기일/NNG', 0.45989760756492615),
#  ('깍/VV', 0.4581388533115387),
#  ('자금/NNG', 0.45350196957588196),
#  ('잔액/NNG', 0.4466343820095062),
#  ('금/NNG', 0.44459277391433716),
#  ('만기/NNG', 0.43802693486213684),
#  ('제때/NNG', 0.43765968084335327),
#  ('대금/NNG', 0.433376669883728),
#  ('달하/VV', 0.4333685338497162),
#  ('공제/NNG', 0.4330146014690399)]

# %%
civil_model.most_similar('보증금/NNG', topn =20)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('전세/NNG', 0.6213095784187317),
#  ('임대차/NNG', 0.6123551726341248),
#  ('임차/NNG', 0.5714862942695618),
#  ('권리금/NNG', 0.5529211163520813),
#  ('월세/NNG', 0.5427432656288147),
#  ('임차인/NNG', 0.5123944282531738),
#  ('원룸/NNG', 0.5093690156936646),
#  ('목적물/NNG', 0.5049268007278442),
#  ('임대/NNG', 0.5039313435554504),
#  ('차임/NNG', 0.4999169707298279),
#  ('입찰/NNG', 0.4866441786289215),
#  ('건물/NNG', 0.4829380214214325),
#  ('임대인/NNG', 0.48186132311820984),
#  ('대출금/NNG', 0.4759770929813385),
#  ('월급/NNG', 0.4600241184234619),
#  ('인도/NNP', 0.45893946290016174),
#  ('반환/NNG', 0.45137330889701843),
#  ('오피스텔/NNG', 0.44689613580703735),
#  ('잔금/NNG', 0.44400158524513245),
#  ('대금/NNG', 0.43978196382522583)]

# %%
civil_model_n.save('model/civil_law_n')

# %%
civil_model = gensim.models.Word2Vec.load('model/civil_law')

# %%
civil_model.most_similar('보증금/NNG', topn =20)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `most_similar` (Method will be removed in 4.0.0, use self.wv.most_similar() instead).
#   """Entry point for launching an IPython kernel.
# [('전세/NNG', 0.6213095784187317),
#  ('임대차/NNG', 0.6123551726341248),
#  ('임차/NNG', 0.5714862942695618),
#  ('권리금/NNG', 0.5529211163520813),
#  ('월세/NNG', 0.5427432656288147),
#  ('임차인/NNG', 0.5123944282531738),
#  ('원룸/NNG', 0.5093690156936646),
#  ('목적물/NNG', 0.5049268007278442),
#  ('임대/NNG', 0.5039313435554504),
#  ('차임/NNG', 0.4999169707298279),
#  ('입찰/NNG', 0.4866441786289215),
#  ('건물/NNG', 0.4829380214214325),
#  ('임대인/NNG', 0.48186132311820984),
#  ('대출금/NNG', 0.4759770929813385),
#  ('월급/NNG', 0.4600241184234619),
#  ('인도/NNP', 0.45893946290016174),
#  ('반환/NNG', 0.45137330889701843),
#  ('오피스텔/NNG', 0.44689613580703735),
#  ('잔금/NNG', 0.44400158524513245),
#  ('대금/NNG', 0.43978196382522583)]

# %%
# Number of clusters
kmeans = KMeans(n_clusters=5)
# Fitting the input data
kmeans = kmeans.fit(civil_model)
# Getting the cluster labels
#labels = kmeans.predict(X)
# Centroid values
#centroids = kmeans.cluster_centers_
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-89-968cece8f73c> in <module>()
#       4 kmeans = KMeans(n_clusters=5)
#       5 # Fitting the input data
# ----> 6 kmeans = kmeans.fit(civil_model)
#       7 # Getting the cluster labels
#       8 #labels = kmeans.predict(X)
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in fit(self, X, y)
#     885         """
#     886         random_state = check_random_state(self.random_state)
# --> 887         X = self._check_fit_data(X)
#     888
#     889         self.cluster_centers_, self.labels_, self.inertia_, self.n_iter_ = \
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/sklearn/cluster/k_means_.py in _check_fit_data(self, X)
#     856     def _check_fit_data(self, X):
# ...

# %%
civil_model_n = gensim.models.Word2Vec.load('model/civil_law_n')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-181-ac6d007e5141> in <module>()
# ----> 1 civil_model_n = gensim.models.Word2Vec.load('model/civil_law_n')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/word2vec.py in load(cls, *args, **kwargs)
#     973         """
#     974         try:
# --> 975             return super(Word2Vec, cls).load(*args, **kwargs)
#     976         except AttributeError:
#     977             logger.info('Model saved using code from earlier Gensim Version. Re-loading old model in a compatible way.')
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/gensim/models/base_any2vec.py in load(cls, *args, **kwargs)
#     627     @classmethod
#     628     def load(cls, *args, **kwargs):
# ...

# %%
from nltk.cluster import KMeansClusterer
import nltk
NUM_CLUSTERS=10
kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
assigned_clusters = kclusterer.cluster(civil_model_n[civil_model_n.wv.vocab], assign_clusters=True)
print (assigned_clusters)
# output: [0, 2, 1, 2, 2, 1, 2, 2, 0, 1, 0, 1, 2, 1,
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:5: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-182-6c1684c7dac4> in <module>()
#       3 NUM_CLUSTERS=10
#       4 kclusterer = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
# ----> 5 assigned_clusters = kclusterer.cluster(civil_model_n[civil_model_n.wv.vocab], assign_clusters=True)
#       6 print (assigned_clusters)
#       7 # output: [0, 2, 1, 2, 2, 1, 2, 2, 0, 1, 0, 1, 2, 1,
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/nltk/cluster/util.py in cluster(self, vectors, assign_clusters, trace)
#      59
# ...

# %%
temp_m = [[0]*0 for i in range(10)]
words = list( civil_model_n.wv.vocab)
for i ,word in enumerate( words):
#    print( word+ ":" + str( assigned_clusters[i]))
    if( word != "0"):
        temp_m[assigned_clusters[i]].append( word)

# %%
len( civil_model_n.wv.vocab)
# Out:
# 2014

# %%
for i in range(10):
    print(i ) 
    print("---------")
    for j in temp_m[i]:
        print(  j ,end=' , ')

    print( "\n")
# Out:
# 0
# ---------
# ...

# %% [markdown]
# #  cluster = 15

# %%
NUM_CLUSTERS=15
kclusterer_15 = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
assigned_clusters_15 = kclusterer_15.cluster(civil_model_n[civil_model_n.wv.vocab], assign_clusters=True)
print (assigned_clusters_15)
# output: [0, 2, 1, 2, 2, 1,
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
temp_m_15 = [[0]*0 for i in range(15)]
words_15 = list( civil_model_n.wv.vocab)
for i ,word in enumerate( words_15):
    temp_m_15[assigned_clusters_15[i]].append( word + ",")

# %%
for i in range(15):
    print(i ) 
    print("---------")
    for j in temp_m_15[i]:
        print(  j )

    print( "\n")
# Out:
# 0
# ---------
# 선임/NNG,
# 구분/NNG,
# 특정/NNG,
# 분배/NNG,
# 반대/NNG,
# 회원/NNG,
# 관리/NNG,
# 예/NNG,
# 후손/NNG,
# 참석/NNG,
# 이사/NNG,
# 운영/NNG,
# 이란/NNP,
# 종국판결/NNP,
# 선정/NNG,
# 비유/NNG,
# 법인/NNG,
# 거주/NNG,
# 지역/NNG,
# 세대주/NNG,
# 문장/NNG,
# 사단/NNG,
# 위임/NNG,
# 질의/NNG,
# 세/NNG,
# 대표/NNG,
# 정관/NNG,
# 자격/NNG,
# 실체/NNG,
# 해임/NNG,
# 감독/NNG,
# 자율/NNG,
# 제사/NNG,
# 명칭/NNG,
# 참여/NNG,
# 본/NNG,
# 규약/NNG,
# 제정/NNG,
# 총회/NNG,
# 임원/NNG,
# 구성/NNG,
# 주주/NNG,
# 입주자/NNG,
# 회의/NNG,
# 의결/NNG,
# 개최/NNG,
# 임시/NNG,
# 소집/NNG,
# 외국인/NNG,
# 종중/NNG,
# 고유/NNG,
# 유사/NNG,
# 적법/NNG,
# 종전/NNG,
# 공고/NNG,
# 단체/NNG,
# 대표자/NNG,
# 관습/NNG,
# 확장/NNG,
# 소재/NNG,
# 면제/NNG,
# 회칙/NNG,
# 국내/NNG,
# 조합원/NNG,
# 조합/NNG,
# 참가/NNG,
# 본래/NNG,
# 종/NNG,
# 수/NNG,
# 등/NNG,
# 문중/NNG,
# 소속/NNG,
# 잠/NNG,
# 정기/NNG,
# 공/NNG,
# 상임/NNG,
# 결의/NNG,
# 현존/NNG,
# 총유/NNG,
# 하자/NNG,
# 조리/NNG,
# 중원/NNG,
# 연고/NNG,
# 존자/NNG,
# 종장/NNG,
# 관례/NNG,
# 종원/NNP,
# 선출/NNG,
# 과반수/NNG,
# 조직/NNG,
# 정족수/NNG,
# 종손/NNG,
# 회장/NNG,
# 종무/NNG,
# 선조/NNG,
# 수호/NNG,
# 종족/NNG,
# 본질/NNG,
# ...

# %% [markdown]
# #  cluster = 20

# %%
NUM_CLUSTERS=20
kclusterer_20 = KMeansClusterer(NUM_CLUSTERS, distance=nltk.cluster.util.cosine_distance, repeats=25)
assigned_clusters_20 = kclusterer_20.cluster(civil_model_n[civil_model_n.wv.vocab], assign_clusters=True)
print (assigned_clusters_20)
# output: [0, 2, 1, 2, 2, 1,
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# ...

# %%
temp_m_20 = [[0]*0 for i in range(20)]
words_20 = list( civil_model_n.wv.vocab)
for i ,word in enumerate( words_20):
    temp_m_20[assigned_clusters_20[i]].append( word + ",")

# %%
import pickle

pickle.dump(kclusterer_20, open( 'kclusterer_20', 'wb'))

#loaded_model = pickle.load(open(filename, 'rb'))

# %%
for i in range(20):
    print(i ) 
    print("---------")
    for j in temp_m_20[i]:
        print(  j )

    print( "\n")
# Out:
# 0
# ---------
# 선임/NNG,
# 회원/NNG,
# 관리/NNG,
# 후손/NNG,
# 이란/NNP,
# 종국판결/NNP,
# 가집행/NNG,
# 선정/NNG,
# 골프/NNG,
# 회원권/NNG,
# 공공/NNG,
# 명부/NNG,
# 무불/NNG,
# 이행자/NNP,
# 활동/NNG,
# 극도/NNG,
# 비유/NNG,
# 지역/NNG,
# 세대주/NNG,
# 문장/NNG,
# 등재/NNG,
# 사단/NNG,
# 질의/NNG,
# 세/NNG,
# 내지/NNP,
# 정관/NNG,
# 자격/NNG,
# 성년/NNG,
# 감독/NNG,
# 제사/NNG,
# 명칭/NNG,
# 참여/NNG,
# 본/NNG,
# 규약/NNG,
# 제정/NNG,
# 총회/NNG,
# 임원/NNG,
# 입주자/NNG,
# 회의/NNG,
# 의결/NNG,
# 개최/NNG,
# 임시/NNG,
# 소집/NNG,
# 종중/NNG,
# 고유/NNG,
# 유사/NNG,
# 공고/NNG,
# 단체/NNG,
# 대표자/NNG,
# 관습/NNG,
# 관습법/NNG,
# 확장/NNG,
# 소재/NNG,
# 회칙/NNG,
# 부여/NNG,
# 박탈/NNG,
# 자치/NNG,
# 국내/NNG,
# 종/NNG,
# 수/NNG,
# 문중/NNG,
# 소속/NNG,
# 정기/NNG,
# 위원회/NNG,
# 상임/NNG,
# 결의/NNG,
# 현존/NNG,
# 조리/NNG,
# 중원/NNG,
# 연고/NNG,
# 존자/NNG,
# 종장/NNG,
# 관례/NNG,
# 종원/NNP,
# 선출/NNG,
# 과반수/NNG,
# 정비/NNG,
# 재건축/NNG,
# 조직/NNG,
# 정족수/NNG,
# 종손/NNG,
# 회장/NNG,
# 종무/NNG,
# 선조/NNG,
# 수호/NNG,
# 자연/NNG,
# 종족/NNG,
# 본질/NNG,
# 구성원/NNG,
# 친목/NNG,
# 집단/NNG,
# 성과/NNG,
# 성별/NNG,
# 구별/NNG,
# 자손/NNG,
# 봉제사/NNG,
# 변화/NNG,
# ...

# %%
assigned_clusters_20
# Out:
# [9,
#  9,
#  18,
#  16,
#  9,
#  11,
#  9,
#  11,
#  3,
#  18,
#  19,
#  5,
#  1,
#  2,
#  9,
#  11,
#  12,
#  9,
#  11,
#  9,
#  11,
#  18,
#  11,
#  19,
#  1,
#  5,
#  5,
#  16,
#  18,
#  18,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  16,
#  9,
#  2,
#  9,
#  9,
#  19,
#  18,
#  7,
#  18,
#  2,
#  5,
#  5,
#  5,
#  5,
#  15,
#  18,
#  8,
#  5,
#  5,
#  5,
#  11,
#  5,
#  17,
#  8,
#  12,
#  5,
#  5,
#  13,
#  5,
#  17,
#  16,
#  16,
#  16,
#  16,
#  16,
#  11,
#  1,
#  14,
#  5,
#  5,
#  10,
#  7,
#  9,
#  9,
#  18,
#  16,
#  15,
#  8,
#  16,
#  1,
#  16,
#  3,
#  16,
#  4,
#  4,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  9,
#  14,
#  9,
#  9,
#  9,
#  9,
#  9,
#  11,
#  9,
#  9,
#  9,
#  9,
#  11,
#  6,
#  17,
#  9,
#  9,
#  16,
#  14,
#  11,
#  9,
#  4,
#  9,
#  10,
#  10,
#  10,
#  14,
#  1,
#  1,
#  0,
#  1,
#  19,
#  1,
#  1,
#  6,
#  1,
#  1,
#  10,
#  10,
#  12,
#  6,
#  6,
#  6,
#  10,
#  4,
#  6,
#  14,
#  6,
#  2,
#  10,
#  16,
#  16,
#  1,
#  7,
#  7,
# ...

# %%
result = kclusterer_20.cluster( civil_model_n['감사/NNG'] , assign_clusters=True )
# Out:
# ...
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-221-fef571929879> in <module>()
# ----> 1 result = kclusterer_20.cluster( civil_model_n['감사/NNG'] , assign_clusters=True )
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/nltk/cluster/util.py in cluster(self, vectors, assign_clusters, trace)
#      59
#      60         # call abstract method to cluster the vectors
# ---> 61         self.cluster_vectorspace(vectors, trace)
#      62
#      63         # assign the vectors to clusters
#
# ...

# %%
civil_model_n['감사/NNG']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([ 1.06200385e+00, -1.99172959e-01,  3.69994193e-02,  4.16835457e-01,
#         1.49337918e-01,  2.12906435e-01,  7.84631491e-01, -1.36576761e-02,
#        -9.40460503e-01,  2.78893203e-01, -4.28935319e-01,  5.77204406e-01,
#        -6.12379432e-01, -5.65818250e-01,  3.52736264e-02,  1.97893396e-01,
#         1.35300025e-01,  7.90417641e-02,  1.71839163e-01, -1.13858521e+00,
#        -1.68288124e+00, -1.51211187e-01,  6.07112348e-02,  8.01496446e-01,
#        -8.27028632e-01, -8.74962747e-01,  6.64062202e-01,  6.25112951e-01,
#         1.16063103e-01, -2.52257079e-01, -2.75919139e-02,  7.75666714e-01,
#        -1.08620965e+00,  4.22291070e-01, -8.95448625e-01,  2.56005049e-01,
# ...

# %%
civil_model_n[civil_model_n.wv.vocab]
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([[ 0.16886185,  0.35850266,  0.58919084, ...,  0.21185891,
#          0.72857374, -0.05812417],
#        [ 0.32143652,  0.03285219, -0.12416968, ..., -0.01991399,
#          0.65061116, -0.03662898],
#        [ 0.15688445,  0.22644256,  0.5839744 , ..., -0.05729016,
#          0.05165331, -0.9376891 ],
#        ...,
#        [ 0.06181106,  0.29985976,  0.57596916, ..., -0.06921355,
#         -0.8717342 , -0.54506725],
#        [ 0.29156741,  0.20119643,  0.05241251, ...,  0.1787134 ,
#          0.03750441,  0.35813767],
#        [ 0.517272  ,  0.44191256,  0.47054815, ...,  0.06546014,
#         -0.6270676 , -0.2986539 ]], dtype=float32)

# %%
civil_model_n['감사/NNG']
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([ 1.06200385e+00, -1.99172959e-01,  3.69994193e-02,  4.16835457e-01,
#         1.49337918e-01,  2.12906435e-01,  7.84631491e-01, -1.36576761e-02,
#        -9.40460503e-01,  2.78893203e-01, -4.28935319e-01,  5.77204406e-01,
#        -6.12379432e-01, -5.65818250e-01,  3.52736264e-02,  1.97893396e-01,
#         1.35300025e-01,  7.90417641e-02,  1.71839163e-01, -1.13858521e+00,
#        -1.68288124e+00, -1.51211187e-01,  6.07112348e-02,  8.01496446e-01,
#        -8.27028632e-01, -8.74962747e-01,  6.64062202e-01,  6.25112951e-01,
#         1.16063103e-01, -2.52257079e-01, -2.75919139e-02,  7.75666714e-01,
#        -1.08620965e+00,  4.22291070e-01, -8.95448625e-01,  2.56005049e-01,
# ...

# %%
kclusterer_20.classify(civil_model_n['감사/NNG'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# 18
